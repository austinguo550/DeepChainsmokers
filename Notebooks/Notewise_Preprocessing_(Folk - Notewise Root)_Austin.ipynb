# %% [markdown]
# # INSTRUCTIONS
#
# Workflow: Run each cell in order. Put or extract data into relevant folders as defined in section 2. Make remaining folders in drive.  **Cells denoted with * may require extra action.**
#
#
# ```
# Folder Structure Suggested for Section 2:
# drive/
#     train_data/ <- input midis go here
#     train_output/
#         graphs/ <- train/val accuracy plots go here
#         intermed/ <- intermediate weights, preprocessing go here
#         stats/ (currently not being used)
#         midi/ <- output midis go here
# ```

# %% [markdown]
# # 1 Imports

# %%
# Import Data Manip, Debug
import glob
import pickle
import numpy as np
import pandas as pd
import pdb
import matplotlib.pyplot as plt

# Import Music21
# !pip install music21
from music21 import converter, instrument, note, chord, stream

# Import Keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import CuDNNLSTM
from keras.layers import CuDNNGRU
from keras.layers import Activation
from keras.layers import Bidirectional
from keras.layers import RepeatVector
from keras.layers import Flatten
from keras.regularizers import L1L2
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint
from keras.callbacks import History

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# Requirement already satisfied: music21 in /usr/local/lib/python3.6/dist-packages (5.5.0)
# Using TensorFlow backend.

# %%
# stuff needed for colaboratory to connect with drive
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 131323 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.1-0ubuntu3~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.1-0ubuntu3~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.1-0ubuntu3~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %% [markdown]
# # 2 Mount and Set Directories*

# %%
# mount drive
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
DATA_FOLDER = 'drive/Project/train_data/folk'
GRAPHS_FOLDER = 'drive/Project/train_output/graphs'
MIDI_OUTPUT_FOLDER = 'drive/Project/train_output/midi'
INTERMED_FOLDER = 'drive/Project/train_output/intermed'
STATS_FOLDER = 'drive/Project/train_output/stats'

# data specific
FOLK_CORPUS = '/folk_'

# SET THIS TO ONE OF ABOVE (ACTION)
CORPUS = FOLK_CORPUS

# %% [markdown]
# # Notewise Root

# %% [markdown]
# # 3 Set Training Parameters*

# %%
# SET PARAMETERS (ACTION)
RESTS = False
ROOT_EXTRACTION = True
DURATION_BATCH_SIZE = 256
NOTE_BATCH_SIZE = 128
# SPECIFY PARAMETERS TO TEST AS LIST
DROPOUTS = 0
MODEL_SIZES = 256
EPOCHS = 10

# %% [markdown]
# # 4 Preprocess Data (MIDI Data Into Notes Corpus and Duration Corpus)

# %%
# Test

notes_corpus = []
durations_corpus = []

for file in glob.glob(DATA_FOLDER + "/*.mid"):
    try:
      print("Extracting MIDI File: ", file)
      midi_stream = converter.parse(file)

      notes = None

      partition = instrument.partitionByInstrument(midi_stream)

      if not RESTS:
        # No rests
        if partition: 
            notes = partition.parts[0].recurse()
        else: 
            notes = midi_stream.flat.notes
      else:
        # With rests
        if partition: 
            notes = partition.parts[0].recurse()
        else: 
            notes = midi_stream.notesAndRests
          
      in_song_notes = []
      in_song_durations = []
      for element in notes:
          in_song_durations.append(element.duration.quarterLength)
          if isinstance(element, note.Note):
              in_song_notes.append(str(element.pitch))
          elif RESTS and isinstance(element, note.Rest):
              in_song_notes.append("R")
          elif isinstance(element, chord.Chord):
              if ROOT_EXTRACTION:
                  in_song_notes.append(element.root().nameWithOctave)
              else:
                  in_song.append('.'.join(str(n) for n in element.normalOrder))
    except:
      pass
    
    notes_corpus.append(in_song_notes)
    durations_corpus.append(in_song_durations)
            
# Write
with open(INTERMED_FOLDER + CORPUS + 'notes_corpus', 'wb+') as filepath:
    pickle.dump(notes_corpus, filepath)
    
with open(INTERMED_FOLDER + CORPUS + 'durations_corpus', 'wb+') as filepath:
    pickle.dump(durations_corpus, filepath)
# Out:
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4971.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4965.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4966.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4976.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4962.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4963.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4981.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4980.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4972.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4979.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4977.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4974.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4982.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4978.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4973.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4988.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4984.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4987.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4975.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4990.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4983.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4986.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4989.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4998.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4985.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4991.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4994.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4992.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4996.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4997.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4999.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5000.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4995.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5001.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5003.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5010.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5009.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5011.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5005.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5004.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4993.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5002.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5008.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5012.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5006.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5021.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5017.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5018.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5015.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5007.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5014.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5019.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5016.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5013.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5024.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5030.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5023.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5022.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5028.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5020.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5031.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5026.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5025.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5036.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5027.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5038.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5033.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5035.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5034.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5040.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5032.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5039.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5037.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5041.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5045.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5044.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5050.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5042.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5048.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5046.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5043.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5047.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5049.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5051.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5057.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5054.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5052.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5029.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5055.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5060.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5058.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5061.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5056.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5053.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5063.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5066.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5059.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5064.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5062.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5065.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4863.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4865.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4862.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4870.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4864.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4875.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4873.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4878.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4880.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4879.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4876.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4881.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4874.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4877.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4872.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4883.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4884.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4887.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4885.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4890.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4886.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4882.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4891.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4889.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4888.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4892.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4893.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4898.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4895.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4900.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4911.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4897.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4894.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4896.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4901.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4899.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4908.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4910.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4916.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4918.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4902.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4920.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4915.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4907.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4919.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4921.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4913.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4912.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4904.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4914.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4917.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4924.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4909.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4905.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4906.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4903.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4928.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4930.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4926.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4927.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4931.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4923.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4936.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4941.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4939.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4925.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4929.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4922.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4937.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4938.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4935.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4932.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4951.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4933.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4934.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4940.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4944.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4948.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4942.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4943.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4949.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4952.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4945.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4946.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4953.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4947.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4950.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4961.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4955.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4956.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4958.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4960.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4954.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4964.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4957.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4959.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4967.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4970.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4968.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4969.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4765.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4763.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4768.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4767.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4769.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4775.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4777.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4779.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4780.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4773.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4772.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4778.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4774.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4781.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4776.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4787.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4783.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4786.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4790.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4785.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4784.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4788.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4791.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4789.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4782.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4801.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4796.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4797.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4793.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4794.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4800.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4795.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4799.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4792.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4798.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4805.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4809.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4802.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4803.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4806.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4811.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4807.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4808.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4804.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4810.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4813.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4819.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4817.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4814.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4818.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4815.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4821.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4816.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4820.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4812.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4825.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4830.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4822.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4826.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4827.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4829.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4824.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4828.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4823.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4831.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4832.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4841.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4836.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4838.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4840.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4834.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4837.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4839.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4835.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4833.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4851.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4845.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4846.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4849.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4844.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4842.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4847.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4843.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4850.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4848.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4860.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4861.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4852.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4856.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4859.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4857.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4858.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4855.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4854.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4853.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4866.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4869.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4871.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4868.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4867.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4663.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4669.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4662.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4673.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4676.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4667.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4678.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4666.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4675.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4672.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4679.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4674.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4681.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4683.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4685.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4680.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4677.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4690.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4682.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4688.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4686.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4687.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4689.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4692.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4696.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4684.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4699.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4691.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4701.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4694.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4697.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4693.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4695.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4708.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4698.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4704.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4706.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4700.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4702.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4707.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4703.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4709.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4711.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4718.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4710.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4713.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4705.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4712.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4715.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4716.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4714.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4721.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4717.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4724.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4723.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4726.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4725.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4720.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4728.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4722.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4719.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4730.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4727.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4738.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4735.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4731.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4729.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4736.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4741.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4734.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4739.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4732.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4740.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4733.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4747.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4743.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4737.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4746.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4750.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4751.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4742.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4748.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4745.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4753.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4744.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4760.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4749.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4759.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4758.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4756.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4755.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4757.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4761.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4754.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4766.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4770.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4752.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4771.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4762.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4764.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4567.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4566.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4565.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4568.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4570.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4574.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4580.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4576.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4591.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4575.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4572.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4578.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4587.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4579.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4577.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4573.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4581.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4588.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4589.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4582.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4583.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4585.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4586.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4584.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4590.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4592.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4593.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4596.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4598.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4599.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4607.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4595.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4594.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4597.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4611.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4601.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4600.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4605.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4602.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4612.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4616.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4603.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4615.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4618.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4619.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4608.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4609.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4604.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4610.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4621.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4606.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4614.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4613.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4620.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4617.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4625.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4631.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4622.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4629.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4627.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4623.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4624.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4630.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4628.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4626.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4634.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4635.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4632.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4639.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4636.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4640.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4641.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4638.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4633.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4637.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4645.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4643.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4647.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4642.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4649.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4648.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4646.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4651.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4644.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4650.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4661.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4658.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4660.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4657.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4653.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4654.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4652.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4656.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4655.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4659.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4670.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4668.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4671.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4665.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4664.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4468.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4466.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4465.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4472.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4473.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4464.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4471.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4478.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4474.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4480.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4479.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4475.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4477.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4483.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4481.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4476.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4487.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4482.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4484.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4486.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4490.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4491.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4489.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4488.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4485.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4492.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4497.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4501.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4495.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4493.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4499.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4500.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4498.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4496.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4494.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4503.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4511.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4510.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4506.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4508.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4507.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4509.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4505.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4504.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4502.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4514.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4512.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4516.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4521.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4520.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4518.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4517.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4513.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4519.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4515.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4526.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4523.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4529.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4522.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4530.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4527.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4528.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4525.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4531.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4524.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4533.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4532.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4537.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4541.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4536.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4534.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4535.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4539.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4542.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4540.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4538.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4544.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4547.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4551.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4548.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4546.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4553.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4550.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4545.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4543.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4549.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4556.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4559.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4555.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4569.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4552.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4560.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4561.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4558.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4564.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4557.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4554.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4563.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4562.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4571.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4367.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4363.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4362.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4365.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4369.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4378.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4380.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4373.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4381.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4375.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4376.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4372.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4377.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4374.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4379.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4384.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4389.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4386.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4388.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4391.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4385.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4387.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4382.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4393.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4390.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4383.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4392.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4394.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4400.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4396.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4395.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4399.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4398.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4397.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4410.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4401.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4411.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4403.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4404.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4402.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4405.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4406.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4409.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4408.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4419.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4407.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4413.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4416.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4412.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4415.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4417.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4420.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4418.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4414.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4429.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4430.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4421.mid
# ...
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune210.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune203.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune211.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune213.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune218.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune215.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune221.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune212.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune217.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune216.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune219.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune220.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune214.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune228.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune225.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune224.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune231.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune222.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune223.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune226.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune227.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune230.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune229.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune233.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune239.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune236.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune238.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune237.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune241.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune232.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune234.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune240.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune235.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune244.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune248.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune242.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune249.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune250.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune245.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune243.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune246.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune247.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune251.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune260.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune252.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune254.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune257.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune255.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune259.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune253.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune258.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune256.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune261.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune269.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune262.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune270.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune265.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune263.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune71.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune69.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune78.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune67.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune70.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune63.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune74.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune76.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune77.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune81.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune72.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune75.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune73.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune89.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune79.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune85.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune86.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune80.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune90.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune84.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune88.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune87.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune83.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune98.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune96.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune82.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune91.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune94.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune99.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune100.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune97.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune95.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune102.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune93.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune107.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune101.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune92.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune108.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune111.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune106.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune105.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune104.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune103.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune110.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune119.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune113.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune109.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune112.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune120.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune114.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune117.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune116.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune121.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune115.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune118.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune122.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune123.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune128.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune126.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune125.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune131.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune130.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune129.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune124.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune127.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune137.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune136.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune133.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune135.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune141.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune132.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune138.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune134.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune139.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune140.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune151.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune148.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune143.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune144.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune145.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune146.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune142.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune147.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune149.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune160.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune158.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune150.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune155.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune152.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune157.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune156.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune153.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune154.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune159.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune163.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune168.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune161.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune170.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune162.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune169.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune11.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune4.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune2.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune7.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune10.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune8.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune6.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune9.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune3.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune5.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune16.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune18.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune19.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune12.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune17.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune14.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune15.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune20.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune21.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune13.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune30.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune24.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune23.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune22.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune25.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune33.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune31.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune28.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune27.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune39.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune29.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune26.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune34.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune41.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune35.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune38.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune36.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune43.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune44.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune37.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune40.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune32.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune47.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune48.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune46.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune45.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune49.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune42.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune53.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune57.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune51.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune50.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune52.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune55.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune60.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune56.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune54.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune59.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune61.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune66.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune58.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune64.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune65.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune62.mid
# Extracting MIDI File:  drive/Project/train_data/folk/sessiontune68.mid

# %% [markdown]
# # 5 Preprocess Corpus Into Train Data

# %% [markdown]
# ## 5.1 Notes Corpus

# %%
# load notes corpus
with open(INTERMED_FOLDER + CORPUS + 'notes_corpus', 'rb') as filepath:
    notes_corpus = pickle.load(filepath)
    
# If doing learning for one song at a time only
flattened_notes_corpus = []
for song_notes in notes_corpus:
    flattened_notes_corpus += song_notes

vocab_size = len(set(flattened_notes_corpus))
print(vocab_size)

# Produce input output sequences
window_size = 60
note_sequence_input = []
next_note_output = []

notes = sorted(set(flattened_notes_corpus))
note2int = dict((note, num) for num, note in enumerate(notes))

for i in range(0, len(notes_corpus)):
    for j in range(0, len(notes_corpus[i]) - window_size):
        current_sequence = [note2int[note] for note in notes_corpus[i][j:window_size+j]]
        next_note = note2int[notes_corpus[i][window_size+j]]
        note_sequence_input.append(current_sequence)
        next_note_output.append(next_note)
# Out:
# 43

# %%
# check train and label shapes
training_data = np.reshape(note_sequence_input, (len(note_sequence_input), window_size , 1))
training_data = training_data / float(vocab_size)
print('Train shape: ' + str(training_data.shape))
training_label = np_utils.to_categorical(next_note_output)
print('Label shape: ' + str(training_label.shape))
# Out:
# Train shape: (649804, 60, 1)
# Label shape: (649804, 43)

# %% [markdown]
# ## 5.2 Durations Corpus

# %%
# load notes corpus
with open(INTERMED_FOLDER + CORPUS + 'durations_corpus', 'rb') as filepath:
    duration_corpus = pickle.load(filepath)

# Learn on one song at a time
flattened_duration_corpus = []
for song_durations in duration_corpus:
    flattened_duration_corpus += song_durations
    
# import collections
# counter = collections.Counter(flattened_duration_corpus)
# print(counter)


duration_vocab_size = len(set(flattened_duration_corpus))
print(duration_vocab_size)

# Produce input output sequences
duration_window_size = 30
duration_sequence_input = []
next_duration_output = []

durations = sorted(set(flattened_duration_corpus))
duration2int = dict((duration, num) for num, duration in enumerate(durations))

print(duration2int)
# # Write
# with open(INTERMED_FOLDER + "/edm_duration_counter", 'wb+') as filepath:
#     pickle.dump(counter, filepath)

for i in range(0, len(duration_corpus)):
    for j in range(0, len(duration_corpus[i]) - duration_window_size):
        current_duration_sequence = [duration2int[note] for note in duration_corpus[i][j:duration_window_size+j]]
        next_duration = duration2int[duration_corpus[i][duration_window_size+j]]
        duration_sequence_input.append(current_duration_sequence)
        next_duration_output.append(next_duration)
# Out:
# 30
# {0.0: 0, 0.25: 1, Fraction(1, 3): 2, 0.5: 3, Fraction(2, 3): 4, 0.75: 5, 1.0: 6, 1.25: 7, Fraction(4, 3): 8, 1.5: 9, Fraction(5, 3): 10, 1.75: 11, 2.0: 12, 2.25: 13, Fraction(7, 3): 14, 2.5: 15, Fraction(8, 3): 16, 3.0: 17, 3.5: 18, 4.0: 19, 4.25: 20, 4.5: 21, 5.0: 22, 5.5: 23, Fraction(17, 3): 24, 6.0: 25, 6.5: 26, 7.0: 27, 7.5: 28, 8.0: 29}

# %%
# check train and label shapes
duration_training_data = np.reshape(duration_sequence_input, (len(duration_sequence_input), duration_window_size , 1))
duration_training_data = duration_training_data / float(duration_vocab_size)
print('Train shape: ' + str(duration_training_data.shape))
duration_training_label = np_utils.to_categorical(next_duration_output)
print('Label shape: ' + str(duration_training_label.shape))
# Out:
# Train shape: (799861, 30, 1)
# Label shape: (799861, 30)

# %% [markdown]
# # 6 Train

# %% [markdown]
# ## 6.1 Helpers to Create Model

# %%
def create_model(network_input, n_vocab, model_size, dropout):
  model = Sequential()
  reg = L1L2(0, 0)
  model.add(LSTM(
      model_size,
      input_shape=(network_input.shape[1], network_input.shape[2]),
      return_sequences=True,
      dropout=dropout, recurrent_dropout=0.3
  ))
  model.add(CuDNNLSTM(model_size, return_sequences=True, kernel_regularizer=reg))
  model.add(Dropout(dropout))
  model.add(CuDNNLSTM(model_size, kernel_regularizer=reg))
  model.add(Dense(128))
  model.add(Dropout(dropout))
  model.add(Dense(n_vocab))
  model.add(Activation('softmax'))
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model

def create_callback_list(model_size, dropout, model_type):
  filepath = INTERMED_FOLDER + '/%skarpathy-model-weights-%s-%s-%s.hdf5' % (CORPUS, model_type, model_size, dropout)
  model_checkpoint = ModelCheckpoint(
    filepath,
    monitor='loss',
    verbose=0,
    save_best_only=True,
    mode='min'
  )
  return [model_checkpoint], filepath

# acc history
def setup_plot(dropout, size):
  plt.title('Model Accuracy vs. Epoc with Dropout=%s Size=%s' % (dropout, size))
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  
def plot_history(history, model_type, dropout, size):
  plt.plot(history.history['acc'], label="%s train accuracy" % model_type)
  plt.plot(history.history['val_acc'], label="%s val accuracy" % model_type)

def save_plot(file_path):
  plt.legend()
  plt.savefig(file_path)
  plt.clf()
  
def predict_duration(model, WEIGHT_PATH):
  # Prediction
  model.load_weights(WEIGHT_PATH)
  starting_sequence = np.random.randint(219, size=duration_window_size)
  pattern_sequence = starting_sequence.tolist()
  prediction_output = []

  duration2note = dict((num, note) for num, note in enumerate(durations))
  print (duration2note)
  
  for i in range(400):
      prediction_input = np.reshape(pattern_sequence, (1, len(pattern_sequence), 1))
      prediction_input = prediction_input / float(duration_vocab_size)

      if i%3 == 0:   
          print('\r', 'Predicting.  Duration: ', i, end='')  
      if i%3 == 1:   
          print('\r', 'Predicting.. Duration: ', i, end='')
      if i%3 == 2:   
          print('\r', 'Predicting...Duration: ', i, end='')
      prediction = model.predict(prediction_input, verbose=0)

      prediction_values = np.arange(len(prediction[0]))
      prediction_prob = np.asarray(list(prediction[0])) / float(sum(prediction[0]))

      # Most probable note prediction
#       index = np.argmax(prediction)
#       note_instance = duration2note[index]
#       prediction_output.append(note_instance)
      index = np.random.choice(prediction_values, 1, p=prediction_prob)
      note_instance = duration2note[int(index[0])]
      prediction_output.append(note_instance)

      pattern_sequence.append(index)
      pattern_sequence = pattern_sequence[1:len(pattern_sequence)]    

  prediction_output = prediction_output[300:len(prediction_output)]

  # Write
  with open(INTERMED_FOLDER + ("%sduration_prediction_output" % CORPUS), 'wb+') as filepath:
      pickle.dump(prediction_output, filepath)
  
  return prediction_output

def predict_note(model, WEIGHT_PATH):
  model.load_weights(WEIGHT_PATH)
  # Prediction
  starting_sequence = np.random.randint(219, size=window_size)
  pattern_sequence = starting_sequence.tolist()
  prediction_output = []

  int2note = dict((num, note) for num, note in enumerate(notes))
  print (int2note)

  for i in range(400):
      prediction_input = np.reshape(pattern_sequence, (1, len(pattern_sequence), 1))
      prediction_input = prediction_input / float(vocab_size)

      if i%3 == 0:   
          print('\r', 'Predicting.  Note: ', i, end='')  
      if i%3 == 1:   
          print('\r', 'Predicting.. Note: ', i, end='')
      if i%3 == 2:   
          print('\r', 'Predicting...Note: ', i, end='')
      prediction = model.predict(prediction_input, verbose=0)

#       prediction_values = np.arange(len(prediction[0]))
#       prediction_prob = np.asarray(list(prediction[0])) / float(sum(prediction[0]))
#       print(prediction_prob)

      # Most probable note prediction
      index = np.argmax(prediction)
      note_instance = int2note[index]
      prediction_output.append(note_instance)

      # Predict based on prob dist
#       index = np.random.choice(prediction_values, 1, p=prediction_prob)
  #     print(index[0])
  #     print(type(index[0]))
#       note_instance = int2note[int(index[0])]
#       prediction_output.append(note_instance)

      pattern_sequence.append(index)
      pattern_sequence = pattern_sequence[1:len(pattern_sequence)]    

  prediction_output = prediction_output[300:len(prediction_output)]
  # Write
  with open(INTERMED_FOLDER + ("%snotes_prediction_output" % CORPUS), 'wb+') as filepath:
      pickle.dump(prediction_output, filepath)
  return prediction_output

def output_midi(prediction_output, duration_prediction_output, dropout, model_size, option):
  offset = 0
  output_notes = []
  for pattern, duration in zip(prediction_output, duration_prediction_output):

      if ('.' in pattern) or pattern.isdigit():
          chord_array = pattern.split('.')
          chord_notes = []
          for note_instance in chord_array:
              note_object = note.Note(int(note_instance))
              note_object.duration.quarterLength = duration
              note_object.storedInstrument = instrument.Piano()
              chord_notes.append(note_object)
          chord_object = chord.Chord(chord_notes)
          chord_object.offset = offset
          output_notes.append(chord_object)
      elif 'R' == pattern:
          note_object = note.Rest()
          note_object.duration.quarterLength = duration
          note_object.offset = offset
          output_notes.append(note_object)
      else:
          note_object = note.Note(pattern)
          note_object.duration.quarterLength = duration
          note_object.offset = offset
          note_object.storedInstrument = instrument.Piano()
          output_notes.append(note_object)

      offset += 0.5

  midi_stream = stream.Stream(output_notes)
  midi_stream.write('midi', fp=MIDI_OUTPUT_FOLDER + CORPUS + '%s_%s_%s.mid' % (option, dropout, model_size))
  print('\nWrote midi...')

# %% [markdown]
# ## 6.2 Preprocessing Optimization

# %%
notes_histories = {}
duration_histories = {}

dropout, model_size = DROPOUTS, MODEL_SIZES
setup_plot(dropout, model_size)
print('Running duration training on notewise with rests:%s and root extraction:%s' % (RESTS, ROOT_EXTRACTION))
duration_callbacks, duration_weight_path = create_callback_list('duration', dropout, model_size)
duration_model = create_model(duration_training_data, duration_training_label.shape[1], model_size, dropout)
duration_histories[(dropout, model_size)] = duration_model.fit(duration_training_data, duration_training_label, epochs=EPOCHS, batch_size=DURATION_BATCH_SIZE, callbacks=duration_callbacks, validation_split=0.2)
plot_history(duration_histories[(dropout, model_size)], 'Durations', dropout, model_size)
# output intermed duration
duration_prediction = predict_duration(duration_model, duration_weight_path)

print('\n\nRunning notes training on d:%s s:%s' % (dropout, model_size))
notes_callbacks, note_weight_path = create_callback_list('notes', dropout, model_size)
notes_model = create_model(training_data, vocab_size, model_size, dropout)
notes_histories[(dropout, model_size)] = notes_model.fit(training_data, training_label, epochs=EPOCHS, batch_size=NOTE_BATCH_SIZE, callbacks=notes_callbacks, validation_split=0.2)
plot_history(notes_histories[(dropout, model_size)], 'Notes', dropout, model_size)
save_plot(GRAPHS_FOLDER + CORPUS + 'dropout=%s_size=%s' % (dropout, model_size))
# output intermed notes
note_prediction = predict_note(notes_model, note_weight_path)

# output final midi
output_midi(note_prediction, duration_prediction, dropout, model_size, "notewise-root")
# Out:
# Running duration training on notewise with rests:True and root extraction:True
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 639888 samples, validate on 159973 samples
# Epoch 1/10
# 639888/639888 [==============================] - 297s 464us/step - loss: 0.9561 - acc: 0.7231 - val_loss: 0.9659 - val_acc: 0.6971
# Epoch 2/10
# 639888/639888 [==============================] - 292s 456us/step - loss: 0.6151 - acc: 0.8101 - val_loss: 0.5959 - val_acc: 0.8111
# Epoch 3/10
# 639888/639888 [==============================] - 293s 457us/step - loss: 0.5096 - acc: 0.8349 - val_loss: 0.5609 - val_acc: 0.8203
# Epoch 4/10
# 639888/639888 [==============================] - 291s 455us/step - loss: 0.4791 - acc: 0.8428 - val_loss: 0.5470 - val_acc: 0.8253
# Epoch 5/10
# 639888/639888 [==============================] - 290s 453us/step - loss: 0.4583 - acc: 0.8486 - val_loss: 0.5402 - val_acc: 0.8272
# Epoch 6/10
# 639888/639888 [==============================] - 291s 455us/step - loss: 0.4378 - acc: 0.8545 - val_loss: 0.5421 - val_acc: 0.8300
# Epoch 7/10
# 639888/639888 [==============================] - 290s 454us/step - loss: 0.4189 - acc: 0.8608 - val_loss: 0.5501 - val_acc: 0.8279
# Epoch 8/10
# 639888/639888 [==============================] - 291s 454us/step - loss: 0.3992 - acc: 0.8675 - val_loss: 0.5579 - val_acc: 0.8308
# Epoch 9/10
# 639888/639888 [==============================] - 292s 457us/step - loss: 0.3800 - acc: 0.8735 - val_loss: 0.5733 - val_acc: 0.8223
# Epoch 10/10
# 639888/639888 [==============================] - 295s 462us/step - loss: 0.3615 - acc: 0.8802 - val_loss: 0.5982 - val_acc: 0.8232
# {0: 0.0, 1: 0.25, 2: Fraction(1, 3), 3: 0.5, 4: Fraction(2, 3), 5: 0.75, 6: 1.0, 7: 1.25, 8: Fraction(4, 3), 9: 1.5, 10: Fraction(5, 3), 11: 1.75, 12: 2.0, 13: 2.25, 14: Fraction(7, 3), 15: 2.5, 16: Fraction(8, 3), 17: 3.0, 18: 3.5, 19: 4.0, 20: 4.25, 21: 4.5, 22: 5.0, 23: 5.5, 24: Fraction(17, 3), 25: 6.0, 26: 6.5, 27: 7.0, 28: 7.5, 29: 8.0}
#  Predicting.  Duration:  399
#
# Running notes training on d:0 s:256
# Train on 519843 samples, validate on 129961 samples
# Epoch 1/10
# 519843/519843 [==============================] - 761s 1ms/step - loss: 2.3194 - acc: 0.2519 - val_loss: 1.9731 - val_acc: 0.3531
# Epoch 2/10
# 519843/519843 [==============================] - 758s 1ms/step - loss: 1.7532 - acc: 0.4123 - val_loss: 1.8361 - val_acc: 0.3915
# Epoch 3/10
# 519843/519843 [==============================] - 759s 1ms/step - loss: 1.6211 - acc: 0.4529 - val_loss: 1.8201 - val_acc: 0.4007
# Epoch 4/10
# 519843/519843 [==============================] - 755s 1ms/step - loss: 1.5276 - acc: 0.4842 - val_loss: 1.8427 - val_acc: 0.4005
# Epoch 5/10
# 519843/519843 [==============================] - 757s 1ms/step - loss: 1.4481 - acc: 0.5102 - val_loss: 1.8758 - val_acc: 0.3956
# Epoch 6/10
# 519843/519843 [==============================] - 761s 1ms/step - loss: 1.3735 - acc: 0.5369 - val_loss: 1.9016 - val_acc: 0.3950
# Epoch 7/10
# 519843/519843 [==============================] - 764s 1ms/step - loss: 1.2988 - acc: 0.5623 - val_loss: 1.9645 - val_acc: 0.3914
# Epoch 8/10
# 519843/519843 [==============================] - 761s 1ms/step - loss: 1.2349 - acc: 0.5856 - val_loss: 2.0363 - val_acc: 0.3820
# Epoch 9/10
# 519843/519843 [==============================] - 760s 1ms/step - loss: 1.1658 - acc: 0.6093 - val_loss: 2.0955 - val_acc: 0.3793
# Epoch 10/10
# 519843/519843 [==============================] - 755s 1ms/step - loss: 1.1030 - acc: 0.6297 - val_loss: 2.1791 - val_acc: 0.3759
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-8cb298e4ed17> in <module>()
#      17 notes_histories[(dropout, model_size)] = notes_model.fit(training_data, training_label, epochs=EPOCHS, batch_size=NOTE_BATCH_SIZE, callbacks=notes_callbacks, validation_split=0.2)
#      18 plot_history(notes_histories[(dropout, model_size)], 'Notes', dropout, model_size)
# ---> 19 save_plot(GRAPHS_FOLDER + EDM_CORPUS + 'dropout=%s_size=%s' % (dropout, model_size))
#      20 # output intermed notes
#      21 note_prediction = predict_note(notes_model, note_weight_path)
#
# NameError: name 'EDM_CORPUS' is not defined

# %%
plot_history(notes_histories[(dropout, model_size)], 'Notes', dropout, model_size)
save_plot(GRAPHS_FOLDER + CORPUS + 'dropout=%s_size=%s' % (dropout, model_size))
# output intermed notes
note_prediction = predict_note(notes_model, note_weight_path)

# output final midi
output_midi(note_prediction, duration_prediction, dropout, model_size, "notewise-root")
# Out:
# {0: 'A3', 1: 'A4', 2: 'A5', 3: 'A6', 4: 'B-3', 5: 'B-4', 6: 'B-5', 7: 'B3', 8: 'B4', 9: 'B5', 10: 'C#4', 11: 'C#5', 12: 'C#6', 13: 'C3', 14: 'C4', 15: 'C5', 16: 'C6', 17: 'D3', 18: 'D4', 19: 'D5', 20: 'D6', 21: 'E-3', 22: 'E-4', 23: 'E-5', 24: 'E-6', 25: 'E3', 26: 'E4', 27: 'E5', 28: 'E6', 29: 'F#3', 30: 'F#4', 31: 'F#5', 32: 'F3', 33: 'F4', 34: 'F5', 35: 'F6', 36: 'G#3', 37: 'G#4', 38: 'G#5', 39: 'G3', 40: 'G4', 41: 'G5', 42: 'G6'}
#  Predicting.  Note:  399
# Wrote midi...

# %% [markdown]
# # Notewise Chord

# %% [markdown]
# # 3 Set Training Parameters*

# %%
# SET PARAMETERS (ACTION)
RESTS = True
ROOT_EXTRACTION = True
DURATION_BATCH_SIZE = 256
NOTE_BATCH_SIZE = 128
# SPECIFY PARAMETERS TO TEST AS LIST
DROPOUTS = 0
MODEL_SIZES = 256
EPOCHS = 10

# %% [markdown]
# # 4 Preprocess Data (MIDI Data Into Notes Corpus and Duration Corpus)

# %%
# Test

notes_corpus = []
durations_corpus = []

for file in glob.glob(DATA_FOLDER + "/*.mid"):
    try:
      print("Extracting MIDI File: ", file)
      midi_stream = converter.parse(file)

      notes = None

      partition = instrument.partitionByInstrument(midi_stream)

      if not RESTS:
        # No rests
        if partition: 
            notes = partition.parts[0].recurse()
        else: 
            notes = midi_stream.flat.notes
      else:
        # With rests
        if partition: 
            notes = partition.parts[0].recurse()
        else: 
            notes = midi_stream.notesAndRests
          
      in_song_notes = []
      in_song_durations = []
      for element in notes:
          in_song_durations.append(element.duration.quarterLength)
          if isinstance(element, note.Note):
              in_song_notes.append(str(element.pitch))
          elif RESTS and isinstance(element, note.Rest):
              in_song_notes.append("R")
          elif isinstance(element, chord.Chord):
              if ROOT_EXTRACTION:
                  in_song_notes.append(element.root().nameWithOctave)
              else:
                  in_song.append('.'.join(str(n) for n in element.normalOrder))
    except:
      pass
    
    notes_corpus.append(in_song_notes)
    durations_corpus.append(in_song_durations)
            
# Write
with open(INTERMED_FOLDER + CORPUS + 'notes_corpus', 'wb+') as filepath:
    pickle.dump(notes_corpus, filepath)
    
with open(INTERMED_FOLDER + CORPUS + 'durations_corpus', 'wb+') as filepath:
    pickle.dump(durations_corpus, filepath)

# %% [markdown]
# # 5 Preprocess Corpus Into Train Data

# %% [markdown]
# ## 5.1 Notes Corpus

# %%
# load notes corpus
with open(INTERMED_FOLDER + CORPUS + 'notes_corpus', 'rb') as filepath:
    notes_corpus = pickle.load(filepath)
    
# If doing learning for one song at a time only
flattened_notes_corpus = []
for song_notes in notes_corpus:
    flattened_notes_corpus += song_notes

vocab_size = len(set(flattened_notes_corpus))
print(vocab_size)

# Produce input output sequences
window_size = 60
note_sequence_input = []
next_note_output = []

notes = sorted(set(flattened_notes_corpus))
note2int = dict((note, num) for num, note in enumerate(notes))

for i in range(0, len(notes_corpus)):
    for j in range(0, len(notes_corpus[i]) - window_size):
        current_sequence = [note2int[note] for note in notes_corpus[i][j:window_size+j]]
        next_note = note2int[notes_corpus[i][window_size+j]]
        note_sequence_input.append(current_sequence)
        next_note_output.append(next_note)

# %%
# check train and label shapes
training_data = np.reshape(note_sequence_input, (len(note_sequence_input), window_size , 1))
training_data = training_data / float(vocab_size)
print('Train shape: ' + str(training_data.shape))
training_label = np_utils.to_categorical(next_note_output)
print('Label shape: ' + str(training_label.shape))

# %% [markdown]
# ## 5.2 Durations Corpus

# %%
# load notes corpus
with open(INTERMED_FOLDER + CORPUS + 'durations_corpus', 'rb') as filepath:
    duration_corpus = pickle.load(filepath)

# Learn on one song at a time
flattened_duration_corpus = []
for song_durations in duration_corpus:
    flattened_duration_corpus += song_durations
    
import collections
counter = collections.Counter(flattened_duration_corpus)
print(counter)


duration_vocab_size = len(set(flattened_duration_corpus))
print(duration_vocab_size)

# Produce input output sequences
duration_window_size = 10
duration_sequence_input = []
next_duration_output = []

durations = sorted(set(flattened_duration_corpus))
duration2int = dict((duration, num) for num, duration in enumerate(durations))

print(duration2int)
# Write
with open(INTERMED_FOLDER + "/edm_duration_counter", 'wb+') as filepath:
    pickle.dump(counter, filepath)

for i in range(0, len(duration_corpus)):
    for j in range(0, len(duration_corpus[i]) - duration_window_size):
        current_duration_sequence = [duration2int[note] for note in duration_corpus[i][j:duration_window_size+j]]
        next_duration = duration2int[duration_corpus[i][duration_window_size+j]]
        duration_sequence_input.append(current_duration_sequence)
        next_duration_output.append(next_duration)

# %%
# check train and label shapes
duration_training_data = np.reshape(duration_sequence_input, (len(duration_sequence_input), duration_window_size , 1))
duration_training_data = duration_training_data / float(duration_vocab_size)
print('Train shape: ' + str(duration_training_data.shape))
duration_training_label = np_utils.to_categorical(next_duration_output)
print('Label shape: ' + str(duration_training_label.shape))

# %% [markdown]
# # 6 Train

# %% [markdown]
# ## 6.1 Helpers to Create Model

# %%
def create_model(network_input, n_vocab, model_size, dropout):
  model = Sequential()
  reg = L1L2(0, 0)
  model.add(LSTM(
      model_size,
      input_shape=(network_input.shape[1], network_input.shape[2]),
      return_sequences=True,
      dropout=dropout, recurrent_dropout=0.3
  ))
  model.add(CuDNNLSTM(model_size, return_sequences=True, kernel_regularizer=reg))
  model.add(Dropout(dropout))
  model.add(CuDNNLSTM(model_size, kernel_regularizer=reg))
  model.add(Dense(128))
  model.add(Dropout(dropout))
  model.add(Dense(n_vocab))
  model.add(Activation('softmax'))
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model

def create_callback_list(model_size, dropout, model_type):
  filepath = INTERMED_FOLDER + '/%skarpathy-model-weights-%s-%s-%s.hdf5' % (CORPUS, model_type, model_size, dropout)
  model_checkpoint = ModelCheckpoint(
    filepath,
    monitor='loss',
    verbose=0,
    save_best_only=True,
    mode='min'
  )
  return [model_checkpoint], filepath

# acc history
def setup_plot(dropout, size):
  plt.title('Model Accuracy vs. Epoc with Dropout=%s Size=%s' % (dropout, size))
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  
def plot_history(history, model_type, dropout, size):
  plt.plot(history.history['acc'], label="%s train accuracy" % model_type)
  plt.plot(history.history['val_acc'], label="%s val accuracy" % model_type)

def save_plot(file_path):
  plt.legend()
  plt.savefig(file_path)
  plt.clf()
  
def predict_duration(model, WEIGHT_PATH):
  # Prediction
  model.load_weights(WEIGHT_PATH)
  starting_sequence = np.random.randint(219, size=duration_window_size)
  pattern_sequence = starting_sequence.tolist()
  prediction_output = []

  duration2note = dict((num, note) for num, note in enumerate(durations))
  print (duration2note)
  
  for i in range(400):
      prediction_input = np.reshape(pattern_sequence, (1, len(pattern_sequence), 1))
      prediction_input = prediction_input / float(duration_vocab_size)

      if i%3 == 0:   
          print('\r', 'Predicting.  Duration: ', i, end='')  
      if i%3 == 1:   
          print('\r', 'Predicting.. Duration: ', i, end='')
      if i%3 == 2:   
          print('\r', 'Predicting...Duration: ', i, end='')
      prediction = model.predict(prediction_input, verbose=0)

      prediction_values = np.arange(len(prediction[0]))
      prediction_prob = np.asarray(list(prediction[0])) / float(sum(prediction[0]))

      # Most probable note prediction
#       index = np.argmax(prediction)
#       note_instance = duration2note[index]
#       prediction_output.append(note_instance)
      index = np.random.choice(prediction_values, 1, p=prediction_prob)
      note_instance = duration2note[int(index[0])]
      prediction_output.append(note_instance)

      pattern_sequence.append(index)
      pattern_sequence = pattern_sequence[1:len(pattern_sequence)]    

  prediction_output = prediction_output[300:len(prediction_output)]

  # Write
  with open(INTERMED_FOLDER + ("%sduration_prediction_output" % CORPUS), 'wb+') as filepath:
      pickle.dump(prediction_output, filepath)
  
  return prediction_output

def predict_note(model, WEIGHT_PATH):
  model.load_weights(WEIGHT_PATH)
  # Prediction
  starting_sequence = np.random.randint(219, size=window_size)
  pattern_sequence = starting_sequence.tolist()
  prediction_output = []

  int2note = dict((num, note) for num, note in enumerate(notes))
  print (int2note)

  for i in range(400):
      prediction_input = np.reshape(pattern_sequence, (1, len(pattern_sequence), 1))
      prediction_input = prediction_input / float(vocab_size)

      if i%3 == 0:   
          print('\r', 'Predicting.  Note: ', i, end='')  
      if i%3 == 1:   
          print('\r', 'Predicting.. Note: ', i, end='')
      if i%3 == 2:   
          print('\r', 'Predicting...Note: ', i, end='')
      prediction = model.predict(prediction_input, verbose=0)

#       prediction_values = np.arange(len(prediction[0]))
#       prediction_prob = np.asarray(list(prediction[0])) / float(sum(prediction[0]))
#       print(prediction_prob)

      # Most probable note prediction
      index = np.argmax(prediction)
      note_instance = int2note[index]
      prediction_output.append(note_instance)

      # Predict based on prob dist
#       index = np.random.choice(prediction_values, 1, p=prediction_prob)
  #     print(index[0])
  #     print(type(index[0]))
#       note_instance = int2note[int(index[0])]
#       prediction_output.append(note_instance)

      pattern_sequence.append(index)
      pattern_sequence = pattern_sequence[1:len(pattern_sequence)]    

  prediction_output = prediction_output[300:len(prediction_output)]
  # Write
  with open(INTERMED_FOLDER + ("%snotes_prediction_output" % CORPUS), 'wb+') as filepath:
      pickle.dump(prediction_output, filepath)
  return prediction_output

def output_midi(prediction_output, duration_prediction_output, dropout, model_size, option):
  offset = 0
  output_notes = []
  for pattern, duration in zip(prediction_output, duration_prediction_output):

      if ('.' in pattern) or pattern.isdigit():
          chord_array = pattern.split('.')
          chord_notes = []
          for note_instance in chord_array:
              note_object = note.Note(int(note_instance))
              note_object.duration.quarterLength = duration
              note_object.storedInstrument = instrument.Piano()
              chord_notes.append(note_object)
          chord_object = chord.Chord(chord_notes)
          chord_object.offset = offset
          output_notes.append(chord_object)
      elif 'R' == pattern:
          note_object = note.Rest()
          note_object.duration.quarterLength = duration
          note_object.offset = offset
          output_notes.append(note_object)
      else:
          note_object = note.Note(pattern)
          note_object.duration.quarterLength = duration
          note_object.offset = offset
          note_object.storedInstrument = instrument.Piano()
          output_notes.append(note_object)

      offset += 0.5

  midi_stream = stream.Stream(output_notes)
  midi_stream.write('midi', fp=MIDI_OUTPUT_FOLDER + CORPUS + '%s_%s_%s.mid' % (option, dropout, model_size))
  print('\nWrote midi...')

# %% [markdown]
# ## 6.2 Preprocessing Optimization

# %%
notes_histories = {}
duration_histories = {}

dropout, model_size = DROPOUTS, MODEL_SIZES
setup_plot(dropout, model_size)
print('Running duration training on notewise with rests:%s and root extraction:%s' % (RESTS, ROOT_EXTRACTION))
duration_callbacks, duration_weight_path = create_callback_list('duration', dropout, model_size)
duration_model = create_model(duration_training_data, duration_vocab_size, model_size, dropout)
duration_histories[(dropout, model_size)] = duration_model.fit(duration_training_data, duration_training_label, epochs=EPOCHS, batch_size=DURATION_BATCH_SIZE, callbacks=duration_callbacks, validation_split=0.2)
plot_history(duration_histories[(dropout, model_size)], 'Durations', dropout, model_size)
# output intermed duration
duration_prediction = predict_duration(duration_model, duration_weight_path)

print('\n\nRunning notes training on d:%s s:%s' % (dropout, model_size))
notes_callbacks, note_weight_path = create_callback_list('notes', dropout, model_size)
notes_model = create_model(training_data, vocab_size, model_size, dropout)
notes_histories[(dropout, model_size)] = notes_model.fit(training_data, training_label, epochs=EPOCHS, batch_size=NOTE_BATCH_SIZE, callbacks=notes_callbacks, validation_split=0.2)
plot_history(notes_histories[(dropout, model_size)], 'Notes', dropout, model_size)
save_plot(GRAPHS_FOLDER + EDM_CORPUS + 'dropout=%s_size=%s' % (dropout, model_size))
# output intermed notes
note_prediction = predict_note(notes_model, note_weight_path)

# output final midi
output_midi(note_prediction, duration_prediction, dropout, model_size, "notewise-chord")
