# %% [markdown]
# # INSTRUCTIONS
#
# Workflow: Run each cell in order. Put or extract data into relevant folders as defined in section 2. Make remaining folders in drive.  **Cells denoted with * may require extra action.**
#
#
# ```
# Folder Structure Suggested for Section 2:
# drive/
#     train_data/ <- input midis go here
#     train_output/
#         graphs/ <- train/val accuracy plots go here
#         intermed/ <- intermediate weights, preprocessing go here
#         stats/ (currently not being used)
#         midi/ <- output midis go here
# ```

# %% [markdown]
# # 1 Imports

# %%
# Import Data Manip, Debug
import glob
import pickle
import numpy as np
import pandas as pd
import pdb
import matplotlib.pyplot as plt

# Import Music21
# !pip install music21
from music21 import converter, instrument, note, chord, stream

# Import Keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import CuDNNLSTM
from keras.layers import CuDNNGRU
from keras.layers import Activation
from keras.layers import Bidirectional
from keras.layers import RepeatVector
from keras.layers import Flatten
from keras.regularizers import L1L2
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint
from keras.callbacks import History

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# Requirement already satisfied: music21 in /usr/local/lib/python3.6/dist-packages (5.5.0)
# Using TensorFlow backend.

# %%
# stuff needed for colaboratory to connect with drive
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 131323 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.1-0ubuntu3~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.1-0ubuntu3~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.1-0ubuntu3~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %% [markdown]
# # 2 Mount and Set Directories*

# %%
# mount drive
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
DATA_FOLDER = 'drive/Project/train_data/rock_melody'
GRAPHS_FOLDER = 'drive/Project/train_output/graphs'
MIDI_OUTPUT_FOLDER = 'drive/Project/train_output/midi'
INTERMED_FOLDER = 'drive/Project/train_output/intermed'
STATS_FOLDER = 'drive/Project/train_output/stats'

# data specific
ROCK_CORPUS = '/rock_'

# SET THIS TO ONE OF ABOVE (ACTION)
CORPUS = ROCK_CORPUS

# %% [markdown]
# # Notewise Root and Rest Learning

# %% [markdown]
# # 3 Set Training Parameters*

# %%
# SET PARAMETERS (ACTION)
RESTS = False
ROOT_EXTRACTION = False
DURATION_BATCH_SIZE = 256
NOTE_BATCH_SIZE = 128
# SPECIFY PARAMETERS TO TEST AS LIST
DROPOUTS = 0
MODEL_SIZES = 256
EPOCHS = 10

# %% [markdown]
# # 4 Preprocess Data (MIDI Data Into Notes Corpus and Duration Corpus)

# %%
# Test

notes_corpus = []
durations_corpus = []

for file in glob.glob(DATA_FOLDER + "/*.mid"):
    try:
      print("Extracting MIDI File: ", file)
      midi_stream = converter.parse(file)

      notes = None

      partition = instrument.partitionByInstrument(midi_stream)

      if not RESTS:
        # No rests
        if partition: 
            notes = partition.parts[0].recurse()
        else: 
            notes = midi_stream.flat.notes
      else:
        # With rests
        if partition: 
            notes = partition.parts[0].recurse()
        else: 
            notes = midi_stream.notesAndRests
          
      in_song_notes = []
      in_song_durations = []
      for element in notes:
          in_song_durations.append(element.duration.quarterLength)
          if isinstance(element, note.Note):
              in_song_notes.append(str(element.pitch))
          elif RESTS and isinstance(element, note.Rest):
              in_song_notes.append("R")
          elif isinstance(element, chord.Chord):
              if ROOT_EXTRACTION:
                  in_song_notes.append(element.root().nameWithOctave)
              else:
                  in_song.append('.'.join(str(n) for n in element.normalOrder))
    except:
      pass
    
    notes_corpus.append(in_song_notes)
    durations_corpus.append(in_song_durations)
            
# Write
with open(INTERMED_FOLDER + CORPUS + 'notes_corpus', 'wb+') as filepath:
    pickle.dump(notes_corpus, filepath)
    
with open(INTERMED_FOLDER + CORPUS + 'durations_corpus', 'wb+') as filepath:
    pickle.dump(durations_corpus, filepath)
# Out:
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2955.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2949.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2950.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2953.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2952.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2951.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2948.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2947.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2946.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2954.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2945.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2939.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2936.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2937.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2940.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2938.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2943.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2933.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2935.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2934.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2932.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2871.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2873.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2870.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2874.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2872.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2931.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2868.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2869.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2867.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2930.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2866.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2865.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7149.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7143.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7146.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7147.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7145.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7144.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7142.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7141.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7139.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7148.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7140.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7138.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7130.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7131.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7132.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7136.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7134.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7135.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7133.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/473.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/474.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7137.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3052.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3049.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3050.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3051.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3047.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3048.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3046.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3045.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3044.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3043.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3042.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3037.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3039.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3035.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3038.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3036.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3041.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3033.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3034.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3032.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3031.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3040.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3030.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3026.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3025.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3027.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3024.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3029.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3021.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3022.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3023.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3020.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3028.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3019.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7161.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7152.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7153.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7154.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7155.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7157.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7158.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7156.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7151.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7159.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/7150.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2583.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2580.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2582.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2581.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2576.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2575.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2584.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2574.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2571.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2569.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2567.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2572.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2570.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2566.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2568.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2565.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2573.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2564.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2563.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2561.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2560.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17666.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17667.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2559.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2558.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17668.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17665.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2562.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17664.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17660.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17661.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17657.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17659.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17663.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17658.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17655.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17656.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17654.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17662.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17653.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17652.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17647.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17645.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17644.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17643.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17646.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17649.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17648.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17651.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17642.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17650.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17641.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2860.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2861.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2613.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2864.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2609.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2610.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2611.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2612.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2863.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2608.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2602.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2603.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2600.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2604.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2605.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2601.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2607.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2599.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2598.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2606.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2597.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2596.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2590.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2593.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2594.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2592.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2591.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3018.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3013.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3012.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3015.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3016.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3014.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3017.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3010.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3011.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3008.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3007.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3003.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3006.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2957.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2999.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3000.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3004.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3001.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2958.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2956.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/3005.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15904.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15900.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1590.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15898.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15901.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15899.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15903.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15896.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15897.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15895.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15894.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15902.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15893.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15885.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15886.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15890.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15889.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15888.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15887.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1589.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17640.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17636.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17634.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17633.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17637.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17635.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17639.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17631.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17632.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17630.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17638.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17629.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17628.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17624.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17627.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17619.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17621.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17622.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17625.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17620.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17623.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17618.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17617.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17626.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17616.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17611.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17612.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17610.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17613.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17615.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17607.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17608.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17609.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17606.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17614.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17605.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17604.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17595.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17598.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17601.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17596.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17600.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17599.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17597.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17594.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17603.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17593.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17602.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17592.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17586.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17589.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17588.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17587.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17591.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17582.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17584.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17585.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17583.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17590.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17581.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17580.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17576.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17578.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17577.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17575.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17574.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17573.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17571.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17572.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17579.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17570.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2588.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2589.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2587.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2595.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2586.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2585.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2577.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2578.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/2579.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15861.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15858.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15856.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15859.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15855.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15857.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15845.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15846.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15844.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15843.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15850.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15851.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1586.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15852.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15853.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15854.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15860.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1585.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15841.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15842.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15840.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15849.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1584.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15837.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15835.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15836.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15839.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15832.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15831.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15833.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15834.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1583.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15838.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15830.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15829.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15821.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15825.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15823.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15820.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15824.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15828.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17569.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17564.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17565.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17566.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17563.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17568.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1598.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17561.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17562.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1597.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17567.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1596.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1595.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15943.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15944.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15942.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15946.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15939.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1594.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15940.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15941.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15937.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15945.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15938.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15936.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15928.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15932.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15929.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15933.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1593.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15930.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15931.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15927.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15935.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15926.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15934.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15925.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15917.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15918.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15921.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1592.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15920.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15919.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15922.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15916.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15924.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15915.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15923.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15914.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15907.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15908.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15910.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15909.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15912.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15911.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1591.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15906.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15913.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15905.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15212.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15221.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15211.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14999.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15000.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15207.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15209.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15208.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14997.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14998.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14996.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15210.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14995.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14994.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14989.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14990.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14991.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14988.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14993.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14987.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14985.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14986.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14984.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14992.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14983.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14982.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14981.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14980.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14974.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14977.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14978.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14976.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14979.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14975.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14973.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1582.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15827.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15819.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15818.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15814.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15815.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15813.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15812.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15817.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15809.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15810.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15811.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15808.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15816.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15807.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15801.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15803.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15800.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15804.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15802.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1580.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15806.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15798.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15799.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15805.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15797.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15796.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15790.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15791.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15793.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15792.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1579.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15795.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15742.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15789.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15741.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15794.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15740.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15884.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15892.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15883.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15891.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15882.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15877.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15878.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1588.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15879.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15880.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15875.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15876.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15874.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15881.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15873.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15872.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15869.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15868.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15867.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1587.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15871.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15864.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15865.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15866.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15863.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15870.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15862.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15265.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15262.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15259.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15261.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15260.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17673.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20301.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20302.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17674.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17671.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17672.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17669.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/17670.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15737.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15738.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15735.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15736.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15734.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15733.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15731.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15732.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15730.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15729.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1265.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1262.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1261.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1263.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1266.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1264.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1260.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1259.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/1258.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14972.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14962.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14963.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14964.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14967.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14968.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14970.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14969.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14961.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14960.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14971.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14959.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14956.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14957.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14958.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14952.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14953.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14954.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14955.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14951.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14950.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/14949.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15739.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15252.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15255.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15253.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15256.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15254.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15258.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15249.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15250.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15251.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15257.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15248.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15247.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15242.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15244.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15241.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15240.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15239.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15243.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15246.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15238.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15237.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15245.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15236.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15235.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15228.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15229.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15231.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15230.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15232.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15234.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15226.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15227.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15225.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15233.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15224.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15223.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15216.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15218.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15217.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15220.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15219.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15222.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15214.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15215.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15213.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4422.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4427.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4426.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4428.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4429.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4430.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4431.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4433.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4435.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4436.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4434.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4437.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4432.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4438.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4440.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4439.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4441.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4447.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4443.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4446.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4442.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4445.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4444.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4448.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4450.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4449.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4451.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4456.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4452.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4453.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4454.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4457.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4455.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4458.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4460.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4459.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4464.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4467.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4461.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4463.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4465.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4466.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4468.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4469.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4470.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4471.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4474.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4473.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4475.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4476.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4477.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4472.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4478.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4479.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4481.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4480.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4482.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4486.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4483.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4487.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4484.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4485.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4488.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4489.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/857.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/858.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/860.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/859.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/862.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/861.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/124.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/122.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/125.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/126.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/199.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/201.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/200.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/197.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/458.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/206.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/462.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/204.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/205.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/203.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/202.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/470.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/472.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/469.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/471.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/468.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/467.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/465.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/466.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/464.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/463.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15264.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15728.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15726.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15727.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/15263.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20006.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20008.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20007.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20009.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20010.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20012.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20011.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20013.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20015.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20019.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20017.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20016.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20020.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20023.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20021.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20022.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20018.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20024.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20025.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20027.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20028.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20026.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20030.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/291.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20032.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20033.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20031.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/20029.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/292.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/295.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/293.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/294.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/296.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/297.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/301.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/298.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/299.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/300.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/302.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/303.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/304.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/305.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/307.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/310.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/309.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/308.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/306.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/312.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/314.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/313.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/315.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/316.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/318.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/319.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/320.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/317.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/321.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/322.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/323.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/325.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/324.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4414.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4416.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4417.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4415.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4413.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/326.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4418.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4420.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4419.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4421.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4425.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4423.mid
# Extracting MIDI File:  drive/Project/train_data/rock_melody/4424.mid

# %% [markdown]
# # 5 Preprocess Corpus Into Train Data

# %% [markdown]
# ## 5.1 Notes Corpus

# %%
# load notes corpus
with open(INTERMED_FOLDER + CORPUS + 'notes_corpus', 'rb') as filepath:
    notes_corpus = pickle.load(filepath)
    
# If doing learning for one song at a time only
flattened_notes_corpus = []
for song_notes in notes_corpus:
    flattened_notes_corpus += song_notes

vocab_size = len(set(flattened_notes_corpus))
print(vocab_size)

# Produce input output sequences
window_size = 60
note_sequence_input = []
next_note_output = []

notes = sorted(set(flattened_notes_corpus))
note2int = dict((note, num) for num, note in enumerate(notes))

for i in range(0, len(notes_corpus)):
    for j in range(0, len(notes_corpus[i]) - window_size):
        current_sequence = [note2int[note] for note in notes_corpus[i][j:window_size+j]]
        next_note = note2int[notes_corpus[i][window_size+j]]
        note_sequence_input.append(current_sequence)
        next_note_output.append(next_note)
# Out:
# 87

# %%
# check train and label shapes
training_data = np.reshape(note_sequence_input, (len(note_sequence_input), window_size , 1))
training_data = training_data / float(vocab_size)
print('Train shape: ' + str(training_data.shape))
training_label = np_utils.to_categorical(next_note_output)
print('Label shape: ' + str(training_label.shape))
# Out:
# Train shape: (27013, 60, 1)
# Label shape: (27013, 86)

# %% [markdown]
# ## 5.2 Durations Corpus

# %%
# load notes corpus
with open(INTERMED_FOLDER + CORPUS + 'durations_corpus', 'rb') as filepath:
    duration_corpus = pickle.load(filepath)

# Learn on one song at a time
flattened_duration_corpus = []
for song_durations in duration_corpus:
    flattened_duration_corpus += song_durations
    
# import collections
# counter = collections.Counter(flattened_duration_corpus)
# print(counter)


duration_vocab_size = len(set(flattened_duration_corpus))
print(duration_vocab_size)

# Produce input output sequences
duration_window_size = 8
duration_sequence_input = []
next_duration_output = []

durations = sorted(set(flattened_duration_corpus))
duration2int = dict((duration, num) for num, duration in enumerate(durations))

print(duration2int)
# # Write
# with open(INTERMED_FOLDER + "/edm_duration_counter", 'wb+') as filepath:
#     pickle.dump(counter, filepath)

for i in range(0, len(duration_corpus)):
    for j in range(0, len(duration_corpus[i]) - duration_window_size):
        current_duration_sequence = [duration2int[note] for note in duration_corpus[i][j:duration_window_size+j]]
        next_duration = duration2int[duration_corpus[i][duration_window_size+j]]
        duration_sequence_input.append(current_duration_sequence)
        next_duration_output.append(next_duration)
# Out:
# 1218
# {0.0: 0, Fraction(1, 12): 1, Fraction(1, 6): 2, 0.25: 3, Fraction(1, 3): 4, Fraction(5, 12): 5, 0.5: 6, Fraction(7, 12): 7, Fraction(2, 3): 8, 0.75: 9, Fraction(5, 6): 10, Fraction(11, 12): 11, 1.0: 12, Fraction(13, 12): 13, Fraction(7, 6): 14, 1.25: 15, Fraction(4, 3): 16, Fraction(17, 12): 17, 1.5: 18, Fraction(19, 12): 19, Fraction(5, 3): 20, 1.75: 21, Fraction(11, 6): 22, Fraction(23, 12): 23, 2.0: 24, Fraction(25, 12): 25, 2.25: 26, Fraction(7, 3): 27, Fraction(29, 12): 28, 2.5: 29, Fraction(31, 12): 30, Fraction(8, 3): 31, 2.75: 32, Fraction(17, 6): 33, Fraction(35, 12): 34, 3.0: 35, Fraction(37, 12): 36, 3.25: 37, Fraction(10, 3): 38, 3.5: 39, Fraction(43, 12): 40, Fraction(11, 3): 41, 3.75: 42, 4.0: 43, Fraction(25, 6): 44, 4.25: 45, Fraction(13, 3): 46, Fraction(53, 12): 47, 4.5: 48, Fraction(14, 3): 49, 4.75: 50, Fraction(29, 6): 51, 5.0: 52, Fraction(61, 12): 53, Fraction(31, 6): 54, 5.25: 55, 5.5: 56, Fraction(17, 3): 57, 5.75: 58, 6.0: 59, 6.25: 60, Fraction(19, 3): 61, 6.5: 62, Fraction(79, 12): 63, Fraction(20, 3): 64, 6.75: 65, 7.0: 66, Fraction(85, 12): 67, Fraction(43, 6): 68, 7.25: 69, Fraction(22, 3): 70, 7.5: 71, Fraction(91, 12): 72, Fraction(23, 3): 73, 7.75: 74, 8.0: 75, Fraction(49, 6): 76, 8.25: 77, Fraction(25, 3): 78, 8.5: 79, Fraction(26, 3): 80, 8.75: 81, Fraction(53, 6): 82, 9.0: 83, Fraction(55, 6): 84, 9.25: 85, Fraction(28, 3): 86, Fraction(113, 12): 87, 9.5: 88, Fraction(29, 3): 89, 9.75: 90, 10.0: 91, 10.25: 92, Fraction(31, 3): 93, 10.5: 94, Fraction(32, 3): 95, 10.75: 96, 11.0: 97, 11.25: 98, Fraction(34, 3): 99, 11.5: 100, Fraction(35, 3): 101, 11.75: 102, 12.0: 103, 12.25: 104, Fraction(37, 3): 105, 12.5: 106, Fraction(38, 3): 107, 12.75: 108, Fraction(77, 6): 109, 13.0: 110, 13.25: 111, 13.5: 112, Fraction(41, 3): 113, 14.0: 114, 14.25: 115, Fraction(43, 3): 116, 14.5: 117, 14.75: 118, 15.0: 119, Fraction(91, 6): 120, 15.25: 121, Fraction(46, 3): 122, 15.5: 123, 15.75: 124, 16.0: 125, 16.25: 126, 16.5: 127, 16.75: 128, Fraction(101, 6): 129, 17.0: 130, 17.25: 131, Fraction(52, 3): 132, 17.5: 133, Fraction(53, 3): 134, 17.75: 135, Fraction(107, 6): 136, 18.0: 137, 18.25: 138, Fraction(55, 3): 139, 18.5: 140, Fraction(56, 3): 141, 18.75: 142, 19.0: 143, 19.25: 144, Fraction(58, 3): 145, 19.5: 146, Fraction(59, 3): 147, 19.75: 148, 20.0: 149, 20.25: 150, 20.5: 151, Fraction(62, 3): 152, 21.0: 153, 21.25: 154, Fraction(64, 3): 155, 21.5: 156, Fraction(65, 3): 157, 21.75: 158, 22.0: 159, 22.25: 160, 22.5: 161, Fraction(68, 3): 162, Fraction(275, 12): 163, 23.0: 164, 23.5: 165, Fraction(283, 12): 166, Fraction(71, 3): 167, 23.75: 168, 24.0: 169, 24.5: 170, Fraction(74, 3): 171, 24.75: 172, 25.0: 173, Fraction(76, 3): 174, 25.5: 175, Fraction(77, 3): 176, 25.75: 177, 26.0: 178, 26.5: 179, Fraction(80, 3): 180, 27.0: 181, 27.25: 182, Fraction(83, 3): 183, 27.75: 184, 28.0: 185, 28.5: 186, Fraction(343, 12): 187, 28.75: 188, 29.0: 189, Fraction(175, 6): 190, 29.5: 191, 30.0: 192, 30.25: 193, Fraction(91, 3): 194, 30.5: 195, 31.0: 196, 31.25: 197, 31.5: 198, Fraction(95, 3): 199, 31.75: 200, 32.0: 201, 32.25: 202, Fraction(97, 3): 203, 32.5: 204, 33.0: 205, 33.25: 206, 33.5: 207, 33.75: 208, 34.0: 209, 34.5: 210, Fraction(104, 3): 211, 34.75: 212, 35.0: 213, 35.25: 214, 35.5: 215, Fraction(107, 3): 216, 35.75: 217, 36.0: 218, 36.5: 219, 37.0: 220, Fraction(445, 12): 221, 37.25: 222, Fraction(112, 3): 223, Fraction(449, 12): 224, 37.5: 225, Fraction(113, 3): 226, 37.75: 227, 38.0: 228, Fraction(115, 3): 229, 38.5: 230, Fraction(116, 3): 231, 39.5: 232, Fraction(119, 3): 233, 39.75: 234, Fraction(479, 12): 235, 40.0: 236, 40.25: 237, 40.5: 238, Fraction(487, 12): 239, 40.75: 240, 41.0: 241, Fraction(124, 3): 242, 41.5: 243, 41.75: 244, 42.0: 245, 42.5: 246, 42.75: 247, 43.0: 248, 44.0: 249, 44.25: 250, 44.5: 251, Fraction(269, 6): 252, 45.0: 253, 45.75: 254, 46.0: 255, Fraction(139, 3): 256, 46.5: 257, 46.75: 258, 47.0: 259, 47.25: 260, Fraction(142, 3): 261, 47.5: 262, 48.0: 263, 48.25: 264, 48.5: ...

# %%
# check train and label shapes
duration_training_data = np.reshape(duration_sequence_input, (len(duration_sequence_input), duration_window_size , 1))
duration_training_data = duration_training_data / float(duration_vocab_size)
print('Train shape: ' + str(duration_training_data.shape))
duration_training_label = np_utils.to_categorical(next_duration_output)
print('Label shape: ' + str(duration_training_label.shape))
# Out:
# Train shape: (45538, 8, 1)
# Label shape: (45538, 1216)

# %% [markdown]
# # 6 Train

# %% [markdown]
# ## 6.1 Helpers to Create Model

# %%
def create_model(network_input, n_vocab, model_size, dropout):
  model = Sequential()
  reg = L1L2(0, 0)
  model.add(LSTM(
      model_size,
      input_shape=(network_input.shape[1], network_input.shape[2]),
      return_sequences=True,
      dropout=dropout, recurrent_dropout=0.3
  ))
  model.add(CuDNNLSTM(model_size, return_sequences=True, kernel_regularizer=reg))
  model.add(Dropout(dropout))
  model.add(CuDNNLSTM(model_size, kernel_regularizer=reg))
  model.add(Dense(128))
  model.add(Dropout(dropout))
  model.add(Dense(n_vocab))
  model.add(Activation('softmax'))
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model

def create_callback_list(model_size, dropout, model_type):
  filepath = INTERMED_FOLDER + '/%skarpathy-model-weights-%s-%s-%s.hdf5' % (CORPUS, model_type, model_size, dropout)
  model_checkpoint = ModelCheckpoint(
    filepath,
    monitor='loss',
    verbose=0,
    save_best_only=True,
    mode='min'
  )
  return [model_checkpoint], filepath

# acc history
def setup_plot(dropout, size):
  plt.title('Model Accuracy vs. Epoc with Dropout=%s Size=%s' % (dropout, size))
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  
def plot_history(history, model_type, dropout, size):
  plt.plot(history.history['acc'], label="%s train accuracy" % model_type)
  plt.plot(history.history['val_acc'], label="%s val accuracy" % model_type)

def save_plot(file_path):
  plt.legend()
  plt.savefig(file_path)
  plt.clf()
  
def predict_duration(model, WEIGHT_PATH):
  # Prediction
  model.load_weights(WEIGHT_PATH)
  starting_sequence = np.random.randint(219, size=duration_window_size)
  pattern_sequence = starting_sequence.tolist()
  prediction_output = []

  duration2note = dict((num, note) for num, note in enumerate(durations))
  print (duration2note)
  
  for i in range(400):
      prediction_input = np.reshape(pattern_sequence, (1, len(pattern_sequence), 1))
      prediction_input = prediction_input / float(duration_vocab_size)

      if i%3 == 0:   
          print('\r', 'Predicting.  Duration: ', i, end='')  
      if i%3 == 1:   
          print('\r', 'Predicting.. Duration: ', i, end='')
      if i%3 == 2:   
          print('\r', 'Predicting...Duration: ', i, end='')
      prediction = model.predict(prediction_input, verbose=0)

      prediction_values = np.arange(len(prediction[0]))
      prediction_prob = np.asarray(list(prediction[0])) / float(sum(prediction[0]))

      # Most probable note prediction
#       index = np.argmax(prediction)
#       note_instance = duration2note[index]
#       prediction_output.append(note_instance)
      index = np.random.choice(prediction_values, 1, p=prediction_prob)
      note_instance = duration2note[int(index[0])]
      prediction_output.append(note_instance)

      pattern_sequence.append(index)
      pattern_sequence = pattern_sequence[1:len(pattern_sequence)]    

  prediction_output = prediction_output[300:len(prediction_output)]

  # Write
  with open(INTERMED_FOLDER + ("%sduration_prediction_output" % CORPUS), 'wb+') as filepath:
      pickle.dump(prediction_output, filepath)
  
  return prediction_output

def predict_note(model, WEIGHT_PATH):
  model.load_weights(WEIGHT_PATH)
  # Prediction
  starting_sequence = np.random.randint(219, size=window_size)
  pattern_sequence = starting_sequence.tolist()
  prediction_output = []

  int2note = dict((num, note) for num, note in enumerate(notes))
  print (int2note)

  for i in range(400):
      prediction_input = np.reshape(pattern_sequence, (1, len(pattern_sequence), 1))
      prediction_input = prediction_input / float(vocab_size)

      if i%3 == 0:   
          print('\r', 'Predicting.  Note: ', i, end='')  
      if i%3 == 1:   
          print('\r', 'Predicting.. Note: ', i, end='')
      if i%3 == 2:   
          print('\r', 'Predicting...Note: ', i, end='')
      prediction = model.predict(prediction_input, verbose=0)

#       prediction_values = np.arange(len(prediction[0]))
#       prediction_prob = np.asarray(list(prediction[0])) / float(sum(prediction[0]))
#       print(prediction_prob)

      # Most probable note prediction
      index = np.argmax(prediction)
      note_instance = int2note[index]
      prediction_output.append(note_instance)

      # Predict based on prob dist
#       index = np.random.choice(prediction_values, 1, p=prediction_prob)
  #     print(index[0])
  #     print(type(index[0]))
#       note_instance = int2note[int(index[0])]
#       prediction_output.append(note_instance)

      pattern_sequence.append(index)
      pattern_sequence = pattern_sequence[1:len(pattern_sequence)]    

  prediction_output = prediction_output[300:len(prediction_output)]
  # Write
  with open(INTERMED_FOLDER + ("%snotes_prediction_output" % CORPUS), 'wb+') as filepath:
      pickle.dump(prediction_output, filepath)
  return prediction_output

def output_midi(prediction_output, duration_prediction_output, dropout, model_size, option):
  offset = 0
  output_notes = []
  for pattern, duration in zip(prediction_output, duration_prediction_output):

      if ('.' in pattern) or pattern.isdigit():
          chord_array = pattern.split('.')
          chord_notes = []
          for note_instance in chord_array:
              note_object = note.Note(int(note_instance))
              note_object.duration.quarterLength = duration
              note_object.storedInstrument = instrument.Piano()
              chord_notes.append(note_object)
          chord_object = chord.Chord(chord_notes)
          chord_object.offset = offset
          output_notes.append(chord_object)
      elif 'R' == pattern:
          note_object = note.Rest()
          note_object.duration.quarterLength = duration
          note_object.offset = offset
          output_notes.append(note_object)
      else:
          note_object = note.Note(pattern)
          note_object.duration.quarterLength = duration
          note_object.offset = offset
          note_object.storedInstrument = instrument.Piano()
          output_notes.append(note_object)

      offset += 0.5

  midi_stream = stream.Stream(output_notes)
  midi_stream.write('midi', fp=MIDI_OUTPUT_FOLDER + CORPUS + '%s_%s_%s.mid' % (option, dropout, model_size))
  print('\nWrote midi...')

# %% [markdown]
# ## 6.2 Preprocessing Optimization

# %%
notes_histories = {}
duration_histories = {}

dropout, model_size = DROPOUTS, MODEL_SIZES
setup_plot(dropout, model_size)
print('Running duration training on notewise with rests:%s and root extraction:%s' % (RESTS, ROOT_EXTRACTION))
duration_callbacks, duration_weight_path = create_callback_list('duration', dropout, model_size)
duration_model = create_model(duration_training_data, duration_training_label.shape[1], model_size, dropout)
print(duration_model.summary())
duration_histories[(dropout, model_size)] = duration_model.fit(duration_training_data, duration_training_label, epochs=EPOCHS, batch_size=DURATION_BATCH_SIZE, callbacks=duration_callbacks, validation_split=0.2)
plot_history(duration_histories[(dropout, model_size)], 'Durations', dropout, model_size)
# output intermed duration
duration_prediction = predict_duration(duration_model, duration_weight_path)

print('\n\nRunning notes training on d:%s s:%s' % (dropout, model_size))
notes_callbacks, note_weight_path = create_callback_list('notes', dropout, model_size)
notes_model = create_model(training_data, training_label.shape[1], model_size, dropout)
notes_histories[(dropout, model_size)] = notes_model.fit(training_data, training_label, epochs=EPOCHS, batch_size=NOTE_BATCH_SIZE, callbacks=notes_callbacks, validation_split=0.2)
plot_history(notes_histories[(dropout, model_size)], 'Notes', dropout, model_size)
save_plot(GRAPHS_FOLDER + CORPUS + 'dropout=%s_size=%s' % (dropout, model_size))
# output intermed notes
note_prediction = predict_note(notes_model, note_weight_path)

# output final midi
output_midi(note_prediction, duration_prediction, dropout, model_size, "notewise-chord")
# Out:
# Running duration training on notewise with rests:False and root extraction:False
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 8, 256)            264192
# _________________________________________________________________
# cu_dnnlstm_5 (CuDNNLSTM)     (None, 8, 256)            526336
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 8, 256)            0
# _________________________________________________________________
# cu_dnnlstm_6 (CuDNNLSTM)     (None, 256)               526336
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1216)              156864
# _________________________________________________________________
# activation_3 (Activation)    (None, 1216)              0
# =================================================================
# Total params: 1,506,624
# Trainable params: 1,506,624
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 36430 samples, validate on 9108 samples
# Epoch 1/10
# 36430/36430 [==============================] - 9s 252us/step - loss: 2.5432 - acc: 0.3535 - val_loss: 2.3391 - val_acc: 0.2860
# Epoch 2/10
# 36430/36430 [==============================] - 7s 190us/step - loss: 2.1720 - acc: 0.3687 - val_loss: 2.3315 - val_acc: 0.2860
# Epoch 3/10
# 36430/36430 [==============================] - 7s 196us/step - loss: 2.1368 - acc: 0.3729 - val_loss: 2.3065 - val_acc: 0.3955
# Epoch 4/10
# 36430/36430 [==============================] - 7s 186us/step - loss: 1.9784 - acc: 0.4676 - val_loss: 2.2872 - val_acc: 0.4289
# Epoch 5/10
# 36430/36430 [==============================] - 7s 185us/step - loss: 1.9191 - acc: 0.4900 - val_loss: 2.2669 - val_acc: 0.4229
# Epoch 6/10
# 36430/36430 [==============================] - 7s 185us/step - loss: 1.8895 - acc: 0.4990 - val_loss: 2.2322 - val_acc: 0.4290
# Epoch 7/10
# 36430/36430 [==============================] - 7s 186us/step - loss: 1.8717 - acc: 0.5006 - val_loss: 2.2327 - val_acc: 0.4209
# Epoch 8/10
# 36430/36430 [==============================] - 7s 189us/step - loss: 1.8581 - acc: 0.5026 - val_loss: 2.2947 - val_acc: 0.4330
# Epoch 9/10
# 36430/36430 [==============================] - 7s 192us/step - loss: 1.8426 - acc: 0.5029 - val_loss: 2.2669 - val_acc: 0.4173
# Epoch 10/10
# 36430/36430 [==============================] - 7s 189us/step - loss: 1.8350 - acc: 0.5038 - val_loss: 2.2731 - val_acc: 0.4246
# {0: 0.0, 1: Fraction(1, 12), 2: Fraction(1, 6), 3: 0.25, 4: Fraction(1, 3), 5: Fraction(5, 12), 6: 0.5, 7: Fraction(7, 12), 8: Fraction(2, 3), 9: 0.75, 10: Fraction(5, 6), 11: Fraction(11, 12), 12: 1.0, 13: Fraction(13, 12), 14: Fraction(7, 6), 15: 1.25, 16: Fraction(4, 3), 17: Fraction(17, 12), 18: 1.5, 19: Fraction(19, 12), 20: Fraction(5, 3), 21: 1.75, 22: Fraction(11, 6), 23: Fraction(23, 12), 24: 2.0, 25: Fraction(25, 12), 26: 2.25, 27: Fraction(7, 3), 28: Fraction(29, 12), 29: 2.5, 30: Fraction(31, 12), 31: Fraction(8, 3), 32: 2.75, 33: Fraction(17, 6), 34: Fraction(35, 12), 35: 3.0, 36: Fraction(37, 12), 37: 3.25, 38: Fraction(10, 3), 39: 3.5, 40: Fraction(43, 12), 41: Fraction(11, 3), 42: 3.75, 43: 4.0, 44: Fraction(25, 6), 45: 4.25, 46: Fraction(13, 3), 47: Fraction(53, 12), 48: 4.5, 49: Fraction(14, 3), 50: 4.75, 51: Fraction(29, 6), 52: 5.0, 53: Fraction(61, 12), 54: Fraction(31, 6), 55: 5.25, 56: 5.5, 57: Fraction(17, 3), 58: 5.75, 59: 6.0, 60: 6.25, 61: Fraction(19, 3), 62: 6.5, 63: Fraction(79, 12), 64: Fraction(20, 3), 65: 6.75, 66: 7.0, 67: Fraction(85, 12), 68: Fraction(43, 6), 69: 7.25, 70: Fraction(22, 3), 71: 7.5, 72: Fraction(91, 12), 73: Fraction(23, 3), 74: 7.75, 75: 8.0, 76: Fraction(49, 6), 77: 8.25, 78: Fraction(25, 3), 79: 8.5, 80: Fraction(26, 3), 81: 8.75, 82: Fraction(53, 6), 83: 9.0, 84: Fraction(55, 6), 85: 9.25, 86: Fraction(28, 3), 87: Fraction(113, 12), 88: 9.5, 89: Fraction(29, 3), 90: 9.75, 91: 10.0, 92: 10.25, 93: Fraction(31, 3), 94: 10.5, 95: Fraction(32, 3), 96: 10.75, 97: 11.0, 98: 11.25, 99: Fraction(34, 3), 100: 11.5, 101: Fraction(35, 3), 102: 11.75, 103: 12.0, 104: 12.25, 105: Fraction(37, 3), 106: 12.5, 107: Fraction(38, 3), 108: 12.75, 109: Fraction(77, 6), 110: 13.0, 111: 13.25, 112: 13.5, 113: Fraction(41, 3), 114: 14.0, 115: 14.25, 116: Fraction(43, 3), 117: 14.5, 118: 14.75, 119: 15.0, 120: Fraction(91, 6), 121: 15.25, 122: Fraction(46, 3), 123: 15.5, 124: 15.75, 125: 16.0, 126: 16.25, 127: 16.5, 128: 16.75, 129: Fraction(101, 6), 130: 17.0, 131: 17.25, 132: Fraction(52, 3), 133: 17.5, 134: Fraction(53, 3), 135: 17.75, 136: Fraction(107, 6), 137: 18.0, 138: 18.25, 139: Fraction(55, 3), 140: 18.5, 141: Fraction(56, 3), 142: 18.75, 143: 19.0, 144: 19.25, 145: Fraction(58, 3), 146: 19.5, 147: Fraction(59, 3), 148: 19.75, 149: 20.0, 150: 20.25, 151: 20.5, 152: Fraction(62, 3), 153: 21.0, 154: 21.25, 155: Fraction(64, 3), 156: 21.5, 157: Fraction(65, 3), 158: 21.75, 159: 22.0, 160: 22.25, 161: 22.5, 162: Fraction(68, 3), 163: Fraction(275, 12), 164: 23.0, 165: 23.5, 166: Fraction(283, 12), 167: Fraction(71, 3), 168: 23.75, 169: 24.0, 170: 24.5, 171: Fraction(74, 3), 172: 24.75, 173: 25.0, 174: Fraction(76, 3), 175: 25.5, 176: Fraction(77, 3), 177: 25.75, 178: 26.0, 179: 26.5, 180: Fraction(80, 3), 181: 27.0, 182: 27.25, 183: Fraction(83, 3), 184: 27.75, 185: 28.0, 186: 28.5, 187: Fraction(343, 12), 188: 28.75, 189: 29.0, 190: Fraction(175, 6), 191: 29.5, 192: 30.0, 193: 30.25, 194: Fraction(91, 3), 195: 30.5, 196: 31.0, 197: 31.25, 198: 31.5, 199: Fraction(95, 3), 200: 31.75, 201: 32.0, 202: 32.25, 203: Fraction(97, 3), 204: 32.5, 205: 33.0, 206: 33.25, 207: 33.5, 208: 33.75, 209: 34.0, 210: 34.5, 211: Fraction(104, 3), 212: 34.75, 213: 35.0, 214: 35.25, 215: 35.5, 216: Fraction(107, 3), 217: 35.75, 218: 36.0, 219: 36.5, 220: 37.0, 221: Fraction(445, 12), 222: 37.25, 223: Fraction(112, 3), 224: Fraction(449, 12), 225: 37.5, 226: Fraction(113, 3), 227: 37.75, 228: 38.0, 229: Fraction(115, 3), 230: 38.5, 231: Fraction(116, 3), 232: 39.5, 233: Fraction(119, 3), 234: 39.75, 235: Fraction(479, 12), 236: 40.0, 237: 40.25, 238: 40.5, 239: Fraction(487, 12), 240: 40.75, 241: 41.0, 242: Fraction(124, 3), 243: 41.5, 244: 41.75, 245: 42.0, 246: 42.5, 247: 42.75, 248: 43.0, 249: 44.0, 250: 44.25, 251: 44.5, 252: Fraction(269, 6), 253: 45.0, 254: 45.75, 255: 46.0, 256: Fraction(139, 3), 257: 46.5, 258: 46.75, 259: 47.0, 260: 47.25, 261: Fraction(142, 3), 262: 47.5, 263: 48.0, 264: 48.25, 265:  ...
#  Predicting.  Duration:  399
#
# Running notes training on d:0 s:256
# Train on 21610 samples, validate on 5403 samples
# Epoch 1/10
# 21610/21610 [==============================] - 37s 2ms/step - loss: 3.6679 - acc: 0.1115 - val_loss: 4.2643 - val_acc: 0.0141
# Epoch 2/10
# 21610/21610 [==============================] - 34s 2ms/step - loss: 3.3594 - acc: 0.1588 - val_loss: 4.0719 - val_acc: 0.0381
# Epoch 3/10
# 21610/21610 [==============================] - 33s 2ms/step - loss: 3.0090 - acc: 0.2038 - val_loss: 4.0711 - val_acc: 0.0485
# Epoch 4/10
# 21610/21610 [==============================] - 34s 2ms/step - loss: 2.7778 - acc: 0.2405 - val_loss: 4.0149 - val_acc: 0.0424
# Epoch 5/10
# 21610/21610 [==============================] - 34s 2ms/step - loss: 2.5025 - acc: 0.2939 - val_loss: 3.9458 - val_acc: 0.2053
# Epoch 6/10
# 21610/21610 [==============================] - 35s 2ms/step - loss: 2.1989 - acc: 0.3584 - val_loss: 4.0724 - val_acc: 0.2071
# Epoch 7/10
# 21610/21610 [==============================] - 35s 2ms/step - loss: 1.9131 - acc: 0.4222 - val_loss: 4.5806 - val_acc: 0.0346
# Epoch 8/10
# 21610/21610 [==============================] - 34s 2ms/step - loss: 1.6658 - acc: 0.4811 - val_loss: 4.4351 - val_acc: 0.0502
# Epoch 9/10
# 21610/21610 [==============================] - 33s 2ms/step - loss: 1.5121 - acc: 0.5177 - val_loss: 4.8513 - val_acc: 0.0444
# Epoch 10/10
# 21610/21610 [==============================] - 34s 2ms/step - loss: 1.3719 - acc: 0.5499 - val_loss: 4.9013 - val_acc: 0.1947
# {0: 'A1', 1: 'A2', 2: 'A3', 3: 'A4', 4: 'A5', 5: 'A6', 6: 'A7', 7: 'B-1', 8: 'B-2', 9: 'B-3', 10: 'B-4', 11: 'B-5', 12: 'B-6', 13: 'B-7', 14: 'B1', 15: 'B2', 16: 'B3', 17: 'B4', 18: 'B5', 19: 'B6', 20: 'B7', 21: 'C#-1', 22: 'C#1', 23: 'C#2', 24: 'C#3', 25: 'C#4', 26: 'C#5', 27: 'C#6', 28: 'C#7', 29: 'C-1', 30: 'C1', 31: 'C2', 32: 'C3', 33: 'C4', 34: 'C5', 35: 'C6', 36: 'C7', 37: 'D1', 38: 'D2', 39: 'D3', 40: 'D4', 41: 'D5', 42: 'D6', 43: 'D7', 44: 'E-1', 45: 'E-2', 46: 'E-3', 47: 'E-4', 48: 'E-5', 49: 'E-6', 50: 'E-7', 51: 'E1', 52: 'E2', 53: 'E3', 54: 'E4', 55: 'E5', 56: 'E6', 57: 'E7', 58: 'F#1', 59: 'F#2', 60: 'F#3', 61: 'F#4', 62: 'F#5', 63: 'F#6', 64: 'F#7', 65: 'F1', 66: 'F2', 67: 'F3', 68: 'F4', 69: 'F5', 70: 'F6', 71: 'F7', 72: 'G#1', 73: 'G#2', 74: 'G#3', 75: 'G#4', 76: 'G#5', 77: 'G#6', 78: 'G#7', 79: 'G1', 80: 'G2', 81: 'G3', 82: 'G4', 83: 'G5', 84: 'G6', 85: 'G7', 86: 'G9'}
#  Predicting.  Note:  399
# Wrote midi...
